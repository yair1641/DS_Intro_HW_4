# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Apr 11 13:12:33 2022

@author: user
"""

path="C:\\Users\\user\\Dropbox\\My PC (Yair-Vostro)\\Documents\\Studies\\Year3\\Semester B\\Introduction To Data Science\\Matalot\\Matalot Python\\My Notebooks\\"
f= open(path+'dests.txt','r')
new_list=[]
for city in f:
    new_list.append(city.strip())
    print(city)
print(new_list)
import os
import urllib
import requests
import json
dic_cities= dict()
for city in new_list:
    api_key = "AIzaSyJtKccblablablablablablaoQmNakbUbl" #fake api_key as Anat told us to do 
    serviceurl ="https://maps.googleapis.com/maps/api/distancematrix/json?"
    parms = dict()
    parms['origins'] ='Jerusalem'
    parms['destinations'] = city
    parms['key'] = api_key
    address= city
    url = serviceurl + urllib.parse.urlencode(parms)
    url2="https://maps.googleapis.com/maps/api/geocode/json?address=%s&key=%s" % (address,api_key)
    try:
        response = requests.get(url)
        response2 = requests.get(url2)
        if not response.status_code == 200 and response2.status_code == 200:
            print("HTTP error-response.status_code")
        else:
             try:
                  response_data =response.json()
                  response2_data= response2.json()
             except:
                        print("response not in valid JSON format")
    except:
        print("Something went wrong with requests.get") 
    response = requests.get(url).json()
    response2 = requests.get(url2).json()
    dic_cities[city] =(response["rows"][0]["elements"][0]["distance"]["text"]
                        ,response["rows"][0]["elements"][0]["duration"]["text"]
                        ,response2["results"][0]["geometry"]["bounds"]["northeast"]["lat"]
                        ,response2["results"][0]["geometry"]["bounds"]["northeast"]["lng"])
print(dic_cities)
list={}
for city in dic_cities:
     temp= dic_cities[city][0][:-3]
     temp=temp.replace(",","")
     int(temp)
     list[city]=temp
threefarthestcities = sorted(list, key=list.get, reverse=True)[:3]
print(threefarthestcities)
# Out:
# Istanbul
#
# Amsterdam
#
# Valletta
#
# Basel
#
# Doha
# <class '_io.TextIOWrapper'>
# ['Istanbul', 'Amsterdam', 'Valletta', 'Basel', 'Doha']
# {'destination_addresses': ['İstanbul, Turkey'], 'origin_addresses': ['Jerusalem, Israel'], 'rows': [{'elements': [{'distance': {'text': '1,809 km', 'value': 1808887}, 'duration': {'text': '20 hours 42 mins', 'value': 74525}, 'status': 'OK'}]}], 'status': 'OK'}
# ...

# %%
# Out:
# {'destination_addresses': ['Doha, Qatar'], 'origin_addresses': ['Jerusalem, Israel'], 'rows': [{'elements': [{'distance': {'text': '2,105 km', 'value': 2104502}, 'duration': {'text': '21 hours 58 mins', 'value': 79103}, 'status': 'OK'}]}], 'status': 'OK'}
# ...
